# %% [markdown]
# # Sources
# - https://github.com/hwd404/FOLD-R-PP (FoldR++ algorithm GitHub repo)
# - https://arxiv.org/abs/2110.07843 (Research paper describing the FoldR++ algorithm by UTD's Dr. Gopal Gupta)

# %%
# importing FOLD-R++ algorithm and its associated utilities

from foldrpp import *
from utils import *

# %%
# setting up classifier and importing and processing data

attributes = ['cap-shape','cap-surface','cap-color','bruises','odor','gill-attachment','gill-spacing','gill-size','gill-color','stalk-shape','stalk-root','stalk-surface-above-ring','stalk-surface-below-ring','stalk-color-above-ring','stalk-color-below-ring','veil-type','veil-color','ring-number','ring-type','spore-print-color','population','habitat']
model = Classifier(attrs=attributes, numeric=[], label='class', pos='p')

data = model.load_data('mushrooms.csv')
data_train, data_test = split_data(data, ratio=0.8, rand=True)
x_train, y_train = split_xy(data_train)
x_test, y_test = split_xy(data_test)

# %%
# using the training data to train the model

model.fit(x_train, y_train, ratio=0.5) 
# ratio is a hyperparameter that represent the proportion of examples in the training data that 
# go against the default conclusion (those in the abnormal case)

# %%
# printing the model's answer set program rule set and determining its accuracy in the test data

print('Explainable answer set program (ASP) rule set to determine if a mushroom is poisonous:')
model.print_asp()
y_test_predictions = model.predict(x_test)
accuracy = get_scores(y_test_predictions, y_test)[0]
print('\nAccuracy: ' + str(accuracy))
# Out:
# Explainable answer set program (ASP) rule set to determine if a mushroom is poisonous:
# class(X,'p') :- not odor(X,'n'), not ab1(X), not ab2(X), not ab3(X).
# class(X,'p') :- spore-print-color(X,'r').
# class(X,'p') :- not gill-size(X,'b'), stalk-surface-below-ring(X,'y').
# class(X,'p') :- cap-surface(X,'g').
# class(X,'p') :- habitat(X,'l'), cap-color(X,'w').
# ab1(X) :- bruises(X,'t'), stalk-root(X,'c').
# ab2(X) :- stalk-root(X,'r').
# ab3(X) :- gill-spacing(X,'w'), bruises(X,'t').
#
# Accuracy: 1.0

# %%
# printing explanations for all test data for why they are poisonous ("answer") or why they are not ("rebuttal")

for i, ex in enumerate(x_test):
    print('Explanation for example number ' + str(i) + ':')
    print(model.explain(ex, all_flag=True))
# Out:
# Explanation for example number 0:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 1:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: f'}
#
# Explanation for example number 2:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [T]ab2(X) :- [T]stalk-root(X,'r').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [T]ab2(X), not [U]ab3(X).
# {'stalk-root: r', 'odor: a', 'bruises: t'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [T]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: y'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: g'}
#
# Explanation for example number 3:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'odor: c', 'bruises: f'}
#
# Explanation for example number 4:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'odor: y', 'bruises: f'}
#
# Explanation for example number 5:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: f', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: g'}
#
# Explanation for example number 6:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: d'}
#
# Explanation for example number 7:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 8:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 9:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [T]ab2(X) :- [T]stalk-root(X,'r').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [T]ab2(X), not [U]ab3(X).
# {'stalk-root: r', 'odor: a', 'bruises: t'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [T]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: y'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: g'}
#
# Explanation for example number 10:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 11:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [T]ab2(X) :- [T]stalk-root(X,'r').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [T]ab2(X), not [U]ab3(X).
# {'stalk-root: r', 'odor: a', 'bruises: t'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [T]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: y'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: g'}
#
# Explanation for example number 12:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: f', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: g'}
#
# Explanation for example number 13:
# rebuttal 1:
# [T]ab1(X) :- [T]bruises(X,'t'), [T]stalk-root(X,'c').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [T]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: a', 'stalk-root: c', 'bruises: t'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: g'}
#
# Explanation for example number 14:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: f'}
#
# Explanation for example number 15:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: g'}
#
# Explanation for example number 16:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: s'}
#
# Explanation for example number 17:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 18:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'odor: c', 'bruises: f'}
#
# Explanation for example number 19:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 20:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 21:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 22:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 23:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [T]ab2(X) :- [T]stalk-root(X,'r').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [T]ab2(X), not [U]ab3(X).
# {'stalk-root: r', 'odor: a', 'bruises: t'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [T]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: y'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: p'}
#
# Explanation for example number 24:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: d'}
#
# Explanation for example number 25:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 26:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 27:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: g'}
#
# Explanation for example number 28:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'odor: y', 'bruises: f'}
#
# Explanation for example number 29:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [F]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: n', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: u'}
#
# Explanation for example number 30:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: f', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: g'}
#
# Explanation for example number 31:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 32:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: k', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: g'}
#
# Explanation for example number 33:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 34:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 35:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: y'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [T]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: l', 'cap-color: n'}
#
# Explanation for example number 36:
# rebuttal 1:
# [T]ab1(X) :- [T]bruises(X,'t'), [T]stalk-root(X,'c').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [T]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: a', 'stalk-root: c', 'bruises: t'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'habitat: m', 'cap-color: w'}
#
# Explanation for example number 37:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'odor: c', 'bruises: f'}
#
# Explanation for example number 38:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'odor: y', 'bruises: f'}
#
# Explanation for example number 39:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 40:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 41:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: f', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: g'}
#
# Explanation for example number 42:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 43:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'odor: f', 'bruises: t'}
#
# Explanation for example number 44:
# rebuttal 1:
# [T]ab1(X) :- [T]bruises(X,'t'), [T]stalk-root(X,'c').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [T]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: a', 'stalk-root: c', 'bruises: t'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: g'}
#
# Explanation for example number 45:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 46:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: d'}
#
# Explanation for example number 47:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 48:
# rebuttal 1:
# [T]ab1(X) :- [T]bruises(X,'t'), [T]stalk-root(X,'c').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [T]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: l', 'stalk-root: c', 'bruises: t'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: g'}
#
# Explanation for example number 49:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: f', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: g'}
#
# Explanation for example number 50:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: s'}
#
# Explanation for example number 51:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'odor: y', 'bruises: f'}
#
# Explanation for example number 52:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: f', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: g'}
#
# Explanation for example number 53:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: s'}
#
# Explanation for example number 54:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 55:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: d'}
#
# Explanation for example number 56:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: g'}
#
# Explanation for example number 57:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: s'}
#
# Explanation for example number 58:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: b', 'habitat: w'}
#
# Explanation for example number 59:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 60:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: f'}
#
# Explanation for example number 61:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: g'}
#
# Explanation for example number 62:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 63:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: f', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: g'}
#
# Explanation for example number 64:
# rebuttal 1:
# [T]ab1(X) :- [T]bruises(X,'t'), [T]stalk-root(X,'c').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [T]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: a', 'stalk-root: c', 'bruises: t'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'habitat: m', 'cap-color: w'}
#
# Explanation for example number 65:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 66:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 67:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 68:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 69:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: s'}
#
# Explanation for example number 70:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: f'}
#
# Explanation for example number 71:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: d'}
#
# Explanation for example number 72:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 73:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: f'}
#
# Explanation for example number 74:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: f', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: g'}
#
# Explanation for example number 75:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: g'}
#
# Explanation for example number 76:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 77:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 78:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [T]ab3(X) :- [T]gill-spacing(X,'w'), [T]bruises(X,'t').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [T]ab3(X).
# {'odor: l', 'stalk-root: b', 'gill-spacing: w', 'bruises: t'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [F]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: n', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: d'}
#
# Explanation for example number 79:
# rebuttal 1:
# [T]ab1(X) :- [T]bruises(X,'t'), [T]stalk-root(X,'c').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [T]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: a', 'stalk-root: c', 'bruises: t'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: g'}
#
# Explanation for example number 80:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: e', 'odor: p', 'bruises: t'}
#
# Explanation for example number 81:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: s'}
#
# Explanation for example number 82:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'odor: y', 'bruises: f'}
#
# Explanation for example number 83:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'odor: y', 'bruises: f'}
#
# Explanation for example number 84:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: s'}
#
# Explanation for example number 85:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: d'}
#
# Explanation for example number 86:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: o'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [T]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: l', 'cap-color: n'}
#
# Explanation for example number 87:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 88:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [T]ab2(X) :- [T]stalk-root(X,'r').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [T]ab2(X), not [U]ab3(X).
# {'stalk-root: r', 'odor: l', 'bruises: t'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [T]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: y'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: p'}
#
# Explanation for example number 89:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [T]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: b', 'gill-spacing: w', 'bruises: f', 'odor: c'}
#
# Explanation for example number 90:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: f'}
#
# Explanation for example number 91:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 92:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 93:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: s'}
#
# Explanation for example number 94:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 95:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: e', 'odor: p', 'bruises: t'}
#
# Explanation for example number 96:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 97:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: f'}
#
# Explanation for example number 98:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: e', 'odor: p', 'bruises: t'}
#
# Explanation for example number 99:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: b'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [T]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: l', 'cap-color: n'}
#
# Explanation for example number 100:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 101:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: d'}
#
# Explanation for example number 102:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: s'}
#
# Explanation for example number 103:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# ...
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: g'}
#
# Explanation for example number 1590:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: w'}
#
# Explanation for example number 1591:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [T]ab2(X) :- [T]stalk-root(X,'r').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [T]ab2(X), not [U]ab3(X).
# {'stalk-root: r', 'odor: l', 'bruises: t'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [T]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: y'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: g'}
#
# Explanation for example number 1592:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: f'}
#
# Explanation for example number 1593:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: f'}
#
# Explanation for example number 1594:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 1595:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'odor: f', 'bruises: t'}
#
# Explanation for example number 1596:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: f'}
#
# Explanation for example number 1597:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 1598:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 1599:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [F]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: n', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: u'}
#
# Explanation for example number 1600:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: f'}
#
# Explanation for example number 1601:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 1602:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 1603:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 1604:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 1605:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 1606:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 1607:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: s'}
#
# Explanation for example number 1608:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'bruises: f', 'odor: f'}
#
# Explanation for example number 1609:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'odor: y', 'bruises: f'}
#
# Explanation for example number 1610:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: p', 'habitat: w'}
#
# Explanation for example number 1611:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [T]ab2(X) :- [T]stalk-root(X,'r').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [T]ab2(X), not [U]ab3(X).
# {'stalk-root: r', 'odor: l', 'bruises: t'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [T]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: y'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: g'}
#
# Explanation for example number 1612:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'bruises: f', 'odor: s'}
#
# Explanation for example number 1613:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: d'}
#
# Explanation for example number 1614:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 1615:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: f', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: s'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: g'}
#
# Explanation for example number 1616:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: d'}
#
# Explanation for example number 1617:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: e', 'odor: p', 'bruises: t'}
#
# Explanation for example number 1618:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 1619:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'gill-spacing: c', 'odor: y', 'bruises: f'}
#
# Explanation for example number 1620:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 1621:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'odor: c', 'bruises: f'}
#
# Explanation for example number 1622:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: c', 'stalk-root: b', 'odor: f', 'bruises: t'}
#
# Explanation for example number 1623:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: f'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 1624:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]cap-surface(X,'g').
# {'cap-surface: y'}
# rebuttal 5:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
