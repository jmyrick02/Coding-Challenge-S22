# %% [markdown]
# # Sources
# - https://github.com/hwd404/FOLD-R-PP (FOLD-R++ algorithm GitHub repo)
# - https://arxiv.org/abs/2110.07843 (Research paper describing the FOLD-R++ algorithm by UTD's Dr. Gopal Gupta)

# %%
# importing FOLD-R++ algorithm and its associated utilities

from foldrpp import *
from utils import *

# %%
# setting up classifier and importing and processing data

attributes = ['cap-shape','cap-surface','cap-color','bruises','odor','gill-attachment','gill-spacing','gill-size','gill-color','stalk-shape','stalk-root','stalk-surface-above-ring','stalk-surface-below-ring','stalk-color-above-ring','stalk-color-below-ring','veil-type','veil-color','ring-number','ring-type','spore-print-color','population','habitat']
model = Classifier(attrs=attributes, numeric=[], label='class', pos='p')

data = model.load_data('mushrooms.csv')
data_train, data_test = split_data(data, ratio=0.8, rand=True)
x_train, y_train = split_xy(data_train)
x_test, y_test = split_xy(data_test)

# %%
# using the training data to train the model

model.fit(x_train, y_train, ratio=0.5) 
# ratio is a hyperparameter that represents the proportion of examples in the training data that 
# go against the default conclusion (those in the abnormal case)

# %%
# printing the model's answer set program rule set and determining its accuracy in the test data

print('Explainable answer set program (ASP) rule set to determine if a mushroom is poisonous:')
model.print_asp()
y_test_predictions = model.predict(x_test)
accuracy = get_scores(y_test_predictions, y_test)[0]
print('\nAccuracy: ' + str(accuracy))
# Out:
# Explainable answer set program (ASP) rule set to determine if a mushroom is poisonous:
# class(X,'p') :- not odor(X,'n'), not ab1(X), not ab2(X), not ab3(X).
# class(X,'p') :- spore-print-color(X,'r').
# class(X,'p') :- not gill-size(X,'b'), stalk-surface-below-ring(X,'y').
# class(X,'p') :- habitat(X,'l'), cap-color(X,'w').
# ab1(X) :- bruises(X,'t'), stalk-root(X,'c').
# ab2(X) :- stalk-root(X,'r').
# ab3(X) :- gill-spacing(X,'w'), bruises(X,'t').
#
# Accuracy: 1.0

# %%
# printing explanations for all test data for why they are poisonous ("answer") or why they are not ("rebuttal")

for i, ex in enumerate(x_test):
    print('Explanation for example number ' + str(i) + ':')
    print(model.explain(ex, all_flag=True))
# Out:
# Explanation for example number 0:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: p', 'gill-spacing: c', 'stalk-root: e'}
#
# Explanation for example number 1:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: c', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 2:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: y'}
#
# Explanation for example number 3:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 4:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'odor: f', 'bruises: f', 'gill-spacing: c'}
#
# Explanation for example number 5:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: y'}
#
# Explanation for example number 6:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [F]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: n', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [T]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: c', 'habitat: l'}
#
# Explanation for example number 7:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 8:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: d', 'cap-color: n'}
#
# Explanation for example number 9:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'odor: f', 'bruises: f', 'gill-spacing: c'}
#
# Explanation for example number 10:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 11:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: c', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 12:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: d', 'cap-color: n'}
#
# Explanation for example number 13:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'odor: f', 'bruises: f', 'gill-spacing: c'}
#
# Explanation for example number 14:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 15:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: o'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [T]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: l'}
#
# Explanation for example number 16:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: f', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: g', 'cap-color: g'}
#
# Explanation for example number 17:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'odor: f', 'bruises: f', 'gill-spacing: c'}
#
# Explanation for example number 18:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: f', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'habitat: g', 'cap-color: w'}
#
# Explanation for example number 19:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: d', 'cap-color: n'}
#
# Explanation for example number 20:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: s'}
#
# Explanation for example number 21:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 22:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'odor: f', 'bruises: f', 'gill-spacing: c'}
#
# Explanation for example number 23:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: y'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [T]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: n', 'habitat: l'}
#
# Explanation for example number 24:
# rebuttal 1:
# [T]ab1(X) :- [T]bruises(X,'t'), [T]stalk-root(X,'c').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [T]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'bruises: t', 'odor: l', 'stalk-root: c'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: m'}
#
# Explanation for example number 25:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 26:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 27:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 28:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 29:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 30:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: s'}
#
# Explanation for example number 31:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: p', 'gill-spacing: c', 'stalk-root: e'}
#
# Explanation for example number 32:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 33:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: c', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 34:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 35:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 36:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [F]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: n', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: u'}
#
# Explanation for example number 37:
# answer 1:
# [T]class(X,'p') :- not [F]gill-size(X,'b'), [T]stalk-surface-below-ring(X,'y').
# {'gill-size: n', 'stalk-surface-below-ring: y'}
#
# Explanation for example number 38:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [T]ab3(X) :- [T]gill-spacing(X,'w'), [T]bruises(X,'t').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [T]ab3(X).
# {'bruises: t', 'gill-spacing: w', 'odor: a', 'stalk-root: b'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: u'}
# rebuttal 3:
# [F]class(X,'p') :- not [F]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: n', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: d'}
#
# Explanation for example number 39:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: p', 'gill-spacing: c', 'stalk-root: e'}
#
# Explanation for example number 40:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: g', 'cap-color: g'}
#
# Explanation for example number 41:
# rebuttal 1:
# [T]ab1(X) :- [T]bruises(X,'t'), [T]stalk-root(X,'c').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [T]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'bruises: t', 'odor: l', 'stalk-root: c'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: m'}
#
# Explanation for example number 42:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: y'}
#
# Explanation for example number 43:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: y'}
#
# Explanation for example number 44:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 45:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [T]ab3(X) :- [T]gill-spacing(X,'w'), [T]bruises(X,'t').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [T]ab3(X).
# {'bruises: t', 'gill-spacing: w', 'odor: a', 'stalk-root: b'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [F]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: n', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: d'}
#
# Explanation for example number 46:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [T]ab2(X) :- [T]stalk-root(X,'r').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [T]ab2(X), not [U]ab3(X).
# {'bruises: t', 'stalk-root: r', 'odor: a'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [T]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: y', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: p'}
#
# Explanation for example number 47:
# answer 1:
# [T]class(X,'p') :- not [F]gill-size(X,'b'), [T]stalk-surface-below-ring(X,'y').
# {'gill-size: n', 'stalk-surface-below-ring: y'}
#
# Explanation for example number 48:
# rebuttal 1:
# [T]ab1(X) :- [T]bruises(X,'t'), [T]stalk-root(X,'c').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [T]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'bruises: t', 'stalk-root: c', 'odor: a'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: g', 'cap-color: y'}
#
# Explanation for example number 49:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'odor: f', 'bruises: f', 'gill-spacing: c'}
#
# Explanation for example number 50:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 51:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 52:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: w'}
#
# Explanation for example number 53:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 54:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 55:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 56:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: w', 'cap-color: b'}
#
# Explanation for example number 57:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: w', 'cap-color: n'}
#
# Explanation for example number 58:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: s'}
#
# Explanation for example number 59:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: s'}
#
# Explanation for example number 60:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [T]ab3(X) :- [T]gill-spacing(X,'w'), [T]bruises(X,'t').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [T]ab3(X).
# {'bruises: t', 'gill-spacing: w', 'odor: l', 'stalk-root: b'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: u'}
# rebuttal 3:
# [F]class(X,'p') :- not [F]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: n', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: d'}
#
# Explanation for example number 61:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: s'}
#
# Explanation for example number 62:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: p', 'gill-spacing: c', 'stalk-root: e'}
#
# Explanation for example number 63:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 64:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 65:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [T]ab2(X) :- [T]stalk-root(X,'r').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [T]ab2(X), not [U]ab3(X).
# {'bruises: t', 'stalk-root: r', 'odor: a'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [T]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: y', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: p'}
#
# Explanation for example number 66:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 67:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: d', 'cap-color: n'}
#
# Explanation for example number 68:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: y'}
#
# Explanation for example number 69:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: y'}
#
# Explanation for example number 70:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 71:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: p', 'gill-spacing: c', 'stalk-root: e'}
#
# Explanation for example number 72:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 73:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: k'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'habitat: g', 'cap-color: w'}
#
# Explanation for example number 74:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: b', 'stalk-surface-below-ring: k'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'habitat: g', 'cap-color: w'}
#
# Explanation for example number 75:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: f', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'habitat: g', 'cap-color: w'}
#
# Explanation for example number 76:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 77:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 78:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'habitat: g', 'cap-color: w'}
#
# Explanation for example number 79:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 80:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: d', 'cap-color: n'}
#
# Explanation for example number 81:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 82:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 83:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'habitat: g', 'cap-color: w'}
#
# Explanation for example number 84:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 85:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: f', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: g', 'cap-color: n'}
#
# Explanation for example number 86:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'odor: f', 'bruises: f', 'gill-spacing: c'}
#
# Explanation for example number 87:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: f', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: g', 'cap-color: n'}
#
# Explanation for example number 88:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'odor: f', 'bruises: f', 'gill-spacing: c'}
#
# Explanation for example number 89:
# rebuttal 1:
# [T]ab1(X) :- [T]bruises(X,'t'), [T]stalk-root(X,'c').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [T]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'bruises: t', 'odor: l', 'stalk-root: c'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: g', 'cap-color: y'}
#
# Explanation for example number 90:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [T]ab2(X) :- [T]stalk-root(X,'r').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [T]ab2(X), not [U]ab3(X).
# {'bruises: t', 'stalk-root: r', 'odor: a'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [T]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: y', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: g', 'cap-color: y'}
#
# Explanation for example number 91:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: y'}
#
# Explanation for example number 92:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: s'}
#
# Explanation for example number 93:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: d', 'cap-color: n'}
#
# Explanation for example number 94:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 95:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 96:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: y'}
#
# Explanation for example number 97:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'odor: f', 'bruises: f', 'gill-spacing: c'}
#
# Explanation for example number 98:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: s'}
#
# Explanation for example number 99:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [F]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: n', 'stalk-surface-below-ring: f'}
# rebuttal 4:
# [F]class(X,'p') :- [T]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: c', 'habitat: l'}
#
# Explanation for example number 100:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 101:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 102:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 103:
# answer 1:
# [T]class(X,'p') :- [T]spore-print-color(X,'r').
# {'spore-print-color: r'}
#
# Explanation for example number 104:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: y'}
#
# Explanation for example number 105:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 106:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: w'}
#
# Explanation for example number 107:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [T]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'gill-spacing: w', 'odor: c', 'bruises: f', 'stalk-root: b'}
#
# Explanation for example number 108:
# rebuttal 1:
# [T]ab1(X) :- [T]bruises(X,'t'), [T]stalk-root(X,'c').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [T]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'bruises: t', 'odor: l', 'stalk-root: c'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: m'}
#
# Explanation for example number 109:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: s'}
#
# Explanation for example number 110:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 111:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: g', 'cap-color: g'}
#
# Explanation for example number 112:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 113:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 114:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [T]ab2(X) :- [T]stalk-root(X,'r').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [T]ab2(X), not [U]ab3(X).
# {'bruises: t', 'stalk-root: r', 'odor: a'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [T]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: y', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: g', 'cap-color: y'}
#
# Explanation for example number 115:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# ...
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'odor: f', 'bruises: f', 'gill-spacing: c'}
#
# Explanation for example number 1586:
# rebuttal 1:
# [T]ab1(X) :- [T]bruises(X,'t'), [T]stalk-root(X,'c').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [T]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'bruises: t', 'odor: l', 'stalk-root: c'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: m'}
#
# Explanation for example number 1587:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [T]ab3(X) :- [T]gill-spacing(X,'w'), [T]bruises(X,'t').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [T]ab3(X).
# {'bruises: t', 'gill-spacing: w', 'odor: l', 'stalk-root: b'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: u'}
# rebuttal 3:
# [F]class(X,'p') :- not [F]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'gill-size: n', 'stalk-surface-below-ring: s'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: y', 'habitat: d'}
#
# Explanation for example number 1588:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 1589:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 1590:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: w'}
#
# Explanation for example number 1591:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: p', 'gill-spacing: c', 'stalk-root: e'}
#
# Explanation for example number 1592:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 1593:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'odor: f', 'bruises: f', 'gill-spacing: c'}
#
# Explanation for example number 1594:
# answer 1:
# [T]class(X,'p') :- [T]spore-print-color(X,'r').
# {'spore-print-color: r'}
#
# Explanation for example number 1595:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: d', 'cap-color: n'}
#
# Explanation for example number 1596:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: p', 'cap-color: c'}
#
# Explanation for example number 1597:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: y'}
#
# Explanation for example number 1598:
# answer 1:
# [T]class(X,'p') :- [T]spore-print-color(X,'r').
# {'spore-print-color: r'}
#
# Explanation for example number 1599:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'odor: f', 'bruises: f', 'gill-spacing: c'}
#
# Explanation for example number 1600:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'habitat: g', 'cap-color: w'}
#
# Explanation for example number 1601:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 1602:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: y'}
#
# Explanation for example number 1603:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: d', 'cap-color: n'}
#
# Explanation for example number 1604:
# answer 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [T]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'bruises: t', 'odor: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 1605:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: y'}
#
# Explanation for example number 1606:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'odor: f', 'bruises: f', 'gill-spacing: c'}
#
# Explanation for example number 1607:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: s'}
#
# Explanation for example number 1608:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 1609:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 1610:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: e', 'habitat: d'}
#
# Explanation for example number 1611:
# rebuttal 1:
# [T]ab1(X) :- [T]bruises(X,'t'), [T]stalk-root(X,'c').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [T]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'bruises: t', 'odor: l', 'stalk-root: c'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'habitat: g', 'cap-color: w'}
#
# Explanation for example number 1612:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: g', 'cap-color: g'}
#
# Explanation for example number 1613:
# rebuttal 1:
# [F]ab1(X) :- [T]bruises(X,'t'), [F]stalk-root(X,'c').
# [T]ab2(X) :- [T]stalk-root(X,'r').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [T]ab2(X), not [U]ab3(X).
# {'bruises: t', 'stalk-root: r', 'odor: a'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: n'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [T]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: y', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: g', 'cap-color: y'}
#
# Explanation for example number 1614:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: s'}
#
# Explanation for example number 1615:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 1616:
# rebuttal 1:
# [T]ab1(X) :- [T]bruises(X,'t'), [T]stalk-root(X,'c').
# [F]class(X,'p') :- not [F]odor(X,'n'), not [T]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'bruises: t', 'odor: l', 'stalk-root: c'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'cap-color: w', 'habitat: m'}
#
# Explanation for example number 1617:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'cap-color: g', 'habitat: d'}
#
# Explanation for example number 1618:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'stalk-root: ?', 'bruises: f', 'gill-spacing: c', 'odor: y'}
#
# Explanation for example number 1619:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: g', 'cap-color: g'}
#
# Explanation for example number 1620:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 1621:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 1622:
# answer 1:
# [F]ab1(X) :- [F]bruises(X,'t'), [F]stalk-root(X,'c').
# [F]ab2(X) :- [F]stalk-root(X,'r').
# [F]ab3(X) :- [F]gill-spacing(X,'w'), [F]bruises(X,'t').
# [T]class(X,'p') :- not [F]odor(X,'n'), not [F]ab1(X), not [F]ab2(X), not [F]ab3(X).
# {'odor: f', 'bruises: f', 'gill-spacing: c', 'stalk-root: b'}
#
# Explanation for example number 1623:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: k'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [T]cap-color(X,'w').
# {'habitat: g', 'cap-color: w'}
#
# Explanation for example number 1624:
# rebuttal 1:
# [F]class(X,'p') :- not [T]odor(X,'n'), not [U]ab1(X), not [U]ab2(X), not [U]ab3(X).
# {'odor: n'}
# rebuttal 2:
# [F]class(X,'p') :- [F]spore-print-color(X,'r').
# {'spore-print-color: w'}
# rebuttal 3:
# [F]class(X,'p') :- not [T]gill-size(X,'b'), [F]stalk-surface-below-ring(X,'y').
# {'stalk-surface-below-ring: s', 'gill-size: b'}
# rebuttal 4:
# [F]class(X,'p') :- [F]habitat(X,'l'), [F]cap-color(X,'w').
# {'habitat: w', 'cap-color: n'}
